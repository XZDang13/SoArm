# %%
from PIL import Image, ImageDraw

# %%
L = Image.open("debug_data/sim_0.png").convert("RGBA")
R = Image.open("real.png").convert("RGBA")

# %%
alpha = 0.5
img = Image.blend(L, R, alpha)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>

# %%
L
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>

# %%
R
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>
