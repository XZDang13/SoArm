# %%
from PIL import Image, ImageDraw

# %%
L = Image.open("sim.png").convert("RGBA")
R = Image.open("real.png").convert("RGBA")

# %%
alpha = 0.5
img = Image.blend(L, R, alpha)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGBA size=1280x720>
