# %%
from PIL import Image

# %%
L = Image.open("sim.png")
R = Image.open("real_1280_720.png")

# %%
L.size
# Out:
# (1280, 720)

# %%
R.size
# Out:
# (1280, 720)

# %%
half_L = L.width // 2
half_R = R.width // 2

left_part = L.crop((0, 0, half_L, L.height))
right_part = R.crop((half_L, 0, R.width, R.height))

out = Image.new("RGB", (half_L + half_R, L.height))
out.paste(left_part, (0, 0))
out.paste(right_part, (half_L, 0))

# %%
out
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
left_part = L.crop((0, 0, half_L, L.height))
right_part = R.crop((0, 0, half_L, R.height))

out = Image.new("RGB", (half_L + half_R, L.height))
out.paste(left_part, (0, 0))
out.paste(right_part, (half_L, 0))

# %%
out
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
