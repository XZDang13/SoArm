# %%
from PIL import Image, ImageDraw

# %%
L = Image.open("replays/img/0b806e6c-9222-4afa-af1d-e25facdd5c42_0_0.jpg").convert("RGBA")
R = Image.open("debug_data/real_0.png").convert("RGBA")

# %%
alpha = 0.5
img = Image.blend(L, R, alpha)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>

# %%
L
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>

# %%
R
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>
