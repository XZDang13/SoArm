# %%
matrix = [[3.39340562e+03, 0.00000000e+00, 6.39509397e+02],
 [0.00000000e+00, 4.51177480e+03, 3.99483052e+02],
 [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]]

# %%
((fx, _, cx), (_, fy, cy), (_, _, _)) = matrix  # fx, fy are in pixels, cx, cy are in pixels
horizontal_aperture = 3 * 640 * 1e-4  # convert to meters
vertical_aperture = 3 * 480 * 1e-4  # convert to meters
focal_length_x = 3 * fx * 1e-4  # convert to meters
focal_length_y = 3 * fy * 1e-4  # convert to meters
focal_length = (focal_length_x + focal_length_y) / 2  # convert to meters

# %%
horizontal_aperture
# Out:
# 0.192

# %%
vertical_aperture
# Out:
# 0.14400000000000002

# %%
focal_length
# Out:
# 1.1857770630000002

# %%
3.39340562e+03
# Out:
# 3393.40562
