# %%
from PIL import Image

# %%
img_3_2 = Image.open("sim_3_2.png").convert("RGBA")
img_4_3 = Image.open("sim_4_3.png").convert("RGBA")

# %%
img_3_2_crop = img_3_2.crop((40, 0, 680, 480))

# %%
img_4_3
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>

# %%
img_3_2_crop
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480>
